# %% [markdown]
# Connected to Python 3.11.4

# %%
# UTF-8
# python 3.11.4


import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('/Users/i0557167/Documents/Git/Statistical-Forecasting/adjcov-dist/data/dataMA.csv')

sanofi_colors = ["#7A00E6","#23004C","#CA8FFF","#007FAD","#F38DE4"]
sns.set_palette(sns.color_palette(sanofi_colors))

df_forecastable_BR = df.loc[(df.is_forecastable == True) & (df.market_code == 'BR')] 
df_forecastable_KR = df.loc[(df.is_forecastable == True) & (df.market_code == 'KR')] 
df_forecastable_TH = df.loc[(df.is_forecastable == True) & (df.market_code == 'TH')] 
df_forecastable_HK = df.loc[(df.is_forecastable == True) & (df.market_code == 'HK')] 
df_forecastable_IN = df.loc[(df.is_forecastable == True) & (df.market_code == 'IN')] 


df_BR = df_forecastable_BR.loc[:,['acov']]
df_KR = df_forecastable_KR.loc[:,['acov']]
df_TH = df_forecastable_TH.loc[:,['acov']]
df_HK = df_forecastable_HK.loc[:,['acov']]
df_IN = df_forecastable_IN.loc[:,['acov']]


combined_dfs = pd.DataFrame({'BR': df_BR['acov'],
                             'KR': df_KR['acov'],
                             'TH': df_TH['acov'],
                             'HK': df_HK['acov'],
                             'IN': df_IN['acov']})
print(combined_dfs.head())

df_BR.describe()
df_KR.describe()
df_TH.describe()
df_HK.describe()
df_IN.describe()

combined_dfs.BR.describe()

#df_forecastable_sort = df_forecastable.sort_values(by='acov')

#df_final = df_forecastable_sort.loc[:,['forecast_item','acov']]

#df_final.describe()

ax = sns.boxplot(data=combined_dfs)

#x, y = ax.lines[0].get_data()



#x = sorted(x.tolist())
#y = sorted(y.tolist())

#gmid_dict = {'DORFLEX': 619108,'NOVALGINA': 333533,'OS_CAL_D': 779523,'DERMACYD': 549502}

#df_final['forecast_item'] = df_final['forecast_item'].map(lambda x: str(x)[4:])
#df_final

#for gmid in gmid_dict.values():
    
 #   x = df_final.loc[df_final.forecast_item == str(gmid)]['acov'].values[0]
  #  ax.text(x, 1+x , list(gmid_dict.keys())[list(gmid_dict.values()).index(gmid)])
   # ax.axvline(x, ymax = 0.35, ls = '--')


#ax.axhline(0.65,ls = '--')
# Out:
#    BR        KR  TH  HK  IN
# 0 NaN  0.333880 NaN NaN NaN
# 1 NaN  0.334443 NaN NaN NaN
# 2 NaN  0.451990 NaN NaN NaN
# 3 NaN  0.351763 NaN NaN NaN
# 4 NaN  0.439371 NaN NaN NaN

# %%
df.head()
# Out:
#   market_code forecast_item        date        baseline item_usage_rule  \
# 0          KR    KR: 805543  2023-10-01  2. Statistical             Use
# 1          KR    KR: 805544  2023-10-01  2. Statistical             Use
# 2          KR    KR: 805545  2023-10-01  2. Statistical             Use
# 3          KR    KR: 805548  2023-10-01       1. Manual          Ignore
# 4          KR    KR: 805549  2023-10-01  2. Statistical             Use
#
#    buckets  intermit  adj_mean  adj_dev      acov  is_forecastable  \
# 0       78  0.000000    1830.0    611.0  0.333880             True
# 1       78  0.000000  135763.0  45405.0  0.334443             True
# 2       78  0.000000   48021.0  21705.0  0.451990             True
# 3       78  0.000000    3346.0   1177.0  0.351763             True
# 4       78  0.083333   19974.0   8776.0  0.439371             True
#
#    is_seasonal
# 0         True
# 1        False
# 2        False
# 3         True
# 4        False

# %%
df.loc[is_forecastable == Fals]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df.loc[is_forecastable == Fals]
#
# NameError: name 'is_forecastable' is not defined

# %%
df.loc[df.is_forecastable == Fals]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df.loc[df.is_forecastable == Fals]
#
# NameError: name 'Fals' is not defined

# %%
df.loc[df.is_forecastable == False]
# Out:
# Empty DataFrame
# Columns: [market_code, forecast_item, date, baseline, item_usage_rule, buckets, intermit, adj_mean, adj_dev, acov, is_forecastable, is_seasonal]
# Index: []

# %%
df.loc[df.is_forecastable == False]
# Out:
# Empty DataFrame
# Columns: [market_code, forecast_item, date, baseline, item_usage_rule, buckets, intermit, adj_mean, adj_dev, acov, is_forecastable, is_seasonal]
# Index: []

# %%
df
# Out:
#     market_code forecast_item        date        baseline item_usage_rule  \
# 0            KR    KR: 805543  2023-10-01  2. Statistical             Use
# 1            KR    KR: 805544  2023-10-01  2. Statistical             Use
# 2            KR    KR: 805545  2023-10-01  2. Statistical             Use
# 3            KR    KR: 805548  2023-10-01       1. Manual          Ignore
# 4            KR    KR: 805549  2023-10-01  2. Statistical             Use
# ..          ...           ...         ...             ...             ...
# 205          TH    TH: 882043  2023-10-01  2. Statistical             Use
# 206          TH    TH: 882044  2023-10-01  2. Statistical             Use
# 207          TH    TH: 882045  2023-10-01  2. Statistical             Use
# 208          TH    TH: 882046  2023-10-01  2. Statistical             Use
# 209          TH    TH: 884938  2023-10-01  2. Statistical             Use
#
#      buckets  intermit  adj_mean  adj_dev      acov  is_forecastable  \
# 0         78  0.000000    1830.0    611.0  0.333880             True
# 1         78  0.000000  135763.0  45405.0  0.334443             True
# 2         78  0.000000   48021.0  21705.0  0.451990             True
# 3         78  0.000000    3346.0   1177.0  0.351763             True
# 4         78  0.083333   19974.0   8776.0  0.439371             True
# ..       ...       ...       ...      ...       ...              ...
# 205       78  0.000000   32137.0  11318.0  0.352180             True
# 206       78  0.000000   27547.0  10403.0  0.377645             True
# 207       78  0.000000    3801.0   1339.0  0.352276             True
# 208       78  0.000000    2325.0   1014.0  0.436129             True
# 209       78  0.000000   50608.0  18789.0  0.371265             True
#
#      is_seasonal
# 0           True
# 1          False
# 2          False
# 3           True
# 4          False
# ..           ...
# 205         True
# 206        False
# 207        False
# 208        False
# 209         True
#
# [210 rows x 12 columns]

# %%
df.loc[df.is_forecastable]
# Out:
#     market_code forecast_item        date        baseline item_usage_rule  \
# 0            KR    KR: 805543  2023-10-01  2. Statistical             Use
# 1            KR    KR: 805544  2023-10-01  2. Statistical             Use
# 2            KR    KR: 805545  2023-10-01  2. Statistical             Use
# 3            KR    KR: 805548  2023-10-01       1. Manual          Ignore
# 4            KR    KR: 805549  2023-10-01  2. Statistical             Use
# ..          ...           ...         ...             ...             ...
# 205          TH    TH: 882043  2023-10-01  2. Statistical             Use
# 206          TH    TH: 882044  2023-10-01  2. Statistical             Use
# 207          TH    TH: 882045  2023-10-01  2. Statistical             Use
# 208          TH    TH: 882046  2023-10-01  2. Statistical             Use
# 209          TH    TH: 884938  2023-10-01  2. Statistical             Use
#
#      buckets  intermit  adj_mean  adj_dev      acov  is_forecastable  \
# 0         78  0.000000    1830.0    611.0  0.333880             True
# 1         78  0.000000  135763.0  45405.0  0.334443             True
# 2         78  0.000000   48021.0  21705.0  0.451990             True
# 3         78  0.000000    3346.0   1177.0  0.351763             True
# 4         78  0.083333   19974.0   8776.0  0.439371             True
# ..       ...       ...       ...      ...       ...              ...
# 205       78  0.000000   32137.0  11318.0  0.352180             True
# 206       78  0.000000   27547.0  10403.0  0.377645             True
# 207       78  0.000000    3801.0   1339.0  0.352276             True
# 208       78  0.000000    2325.0   1014.0  0.436129             True
# 209       78  0.000000   50608.0  18789.0  0.371265             True
#
#      is_seasonal
# 0           True
# 1          False
# 2          False
# 3           True
# 4          False
# ..           ...
# 205         True
# 206        False
# 207        False
# 208        False
# 209         True
#
# [210 rows x 12 columns]

# %%
df.loc[df.is_forecastable == False]
# Out:
# Empty DataFrame
# Columns: [market_code, forecast_item, date, baseline, item_usage_rule, buckets, intermit, adj_mean, adj_dev, acov, is_forecastable, is_seasonal]
# Index: []

# %%
df.is_forecastable.unique()
# Out:
# array([ True])

# %%
df.is_forecastable.unique()
# Out:
# array([ True])

# %%
# UTF-8
# python 3.11.4


import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('/Users/i0557167/Documents/Git/Statistical-Forecasting/adjcov-dist/data/dataAL.csv')

sanofi_colors = ["#7A00E6","#23004C","#CA8FFF","#007FAD","#F38DE4"]
sns.set_palette(sns.color_palette(sanofi_colors))

df_forecastable_BR = df.loc[(df.is_forecastable == True) & (df.market_code == 'BR')] 
df_forecastable_KR = df.loc[(df.is_forecastable == True) & (df.market_code == 'KR')] 
df_forecastable_TH = df.loc[(df.is_forecastable == True) & (df.market_code == 'TH')] 
df_forecastable_HK = df.loc[(df.is_forecastable == True) & (df.market_code == 'HK')] 
df_forecastable_IN = df.loc[(df.is_forecastable == True) & (df.market_code == 'IN')] 


df_BR = df_forecastable_BR.loc[:,['acov']]
df_KR = df_forecastable_KR.loc[:,['acov']]
df_TH = df_forecastable_TH.loc[:,['acov']]
df_HK = df_forecastable_HK.loc[:,['acov']]
df_IN = df_forecastable_IN.loc[:,['acov']]


combined_dfs = pd.DataFrame({'BR': df_BR['acov'],
                             'KR': df_KR['acov'],
                             'TH': df_TH['acov'],
                             'HK': df_HK['acov'],
                             'IN': df_IN['acov']})
print(combined_dfs.head())

df_BR.describe()
df_KR.describe()
df_TH.describe()
df_HK.describe()
df_IN.describe()

combined_dfs.BR.describe()

#df_forecastable_sort = df_forecastable.sort_values(by='acov')

#df_final = df_forecastable_sort.loc[:,['forecast_item','acov']]

#df_final.describe()

ax = sns.boxplot(data=combined_dfs)

#x, y = ax.lines[0].get_data()



#x = sorted(x.tolist())
#y = sorted(y.tolist())

#gmid_dict = {'DORFLEX': 619108,'NOVALGINA': 333533,'OS_CAL_D': 779523,'DERMACYD': 549502}

#df_final['forecast_item'] = df_final['forecast_item'].map(lambda x: str(x)[4:])
#df_final

#for gmid in gmid_dict.values():
    
 #   x = df_final.loc[df_final.forecast_item == str(gmid)]['acov'].values[0]
  #  ax.text(x, 1+x , list(gmid_dict.keys())[list(gmid_dict.values()).index(gmid)])
   # ax.axvline(x, ymax = 0.35, ls = '--')


#ax.axhline(0.65,ls = '--')
# Out:
# Empty DataFrame
# Columns: [BR, KR, TH, HK, IN]
# Index: []

# %%
df.is_forecastable.unique()
# Out:
# array([False,  True])

# %%
# UTF-8
# python 3.11.4


import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('/Users/i0557167/Documents/Git/Statistical-Forecasting/adjcov-dist/data/dataMA.csv')

sanofi_colors = ["#7A00E6","#23004C","#CA8FFF","#007FAD","#F38DE4"]
sns.set_palette(sns.color_palette(sanofi_colors))

df_forecastable_BR = df.loc[(df.is_forecastable == True) & (df.market_code == 'BR')] 
df_forecastable_KR = df.loc[(df.is_forecastable == True) & (df.market_code == 'KR')] 
df_forecastable_TH = df.loc[(df.is_forecastable == True) & (df.market_code == 'TH')] 
df_forecastable_HK = df.loc[(df.is_forecastable == True) & (df.market_code == 'HK')] 
df_forecastable_IN = df.loc[(df.is_forecastable == True) & (df.market_code == 'IN')] 


df_BR = df_forecastable_BR.loc[:,['acov']]
df_KR = df_forecastable_KR.loc[:,['acov']]
df_TH = df_forecastable_TH.loc[:,['acov']]
df_HK = df_forecastable_HK.loc[:,['acov']]
df_IN = df_forecastable_IN.loc[:,['acov']]


combined_dfs = pd.DataFrame({'BR': df_BR['acov'],
                             'KR': df_KR['acov'],
                             'TH': df_TH['acov'],
                             'HK': df_HK['acov'],
                             'IN': df_IN['acov']})
print(combined_dfs.head())

df_BR.describe()
df_KR.describe()
df_TH.describe()
df_HK.describe()
df_IN.describe()

combined_dfs.BR.describe()

#df_forecastable_sort = df_forecastable.sort_values(by='acov')

#df_final = df_forecastable_sort.loc[:,['forecast_item','acov']]

#df_final.describe()

ax = sns.boxplot(data=combined_dfs)

#x, y = ax.lines[0].get_data()



#x = sorted(x.tolist())
#y = sorted(y.tolist())

#gmid_dict = {'DORFLEX': 619108,'NOVALGINA': 333533,'OS_CAL_D': 779523,'DERMACYD': 549502}

#df_final['forecast_item'] = df_final['forecast_item'].map(lambda x: str(x)[4:])
#df_final

#for gmid in gmid_dict.values():
    
 #   x = df_final.loc[df_final.forecast_item == str(gmid)]['acov'].values[0]
  #  ax.text(x, 1+x , list(gmid_dict.keys())[list(gmid_dict.values()).index(gmid)])
   # ax.axvline(x, ymax = 0.35, ls = '--')


#ax.axhline(0.65,ls = '--')
# Out:
#           BR  KR  TH  HK  IN
# 0   0.512710 NaN NaN NaN NaN
# 1   0.503969 NaN NaN NaN NaN
# 6   0.491780 NaN NaN NaN NaN
# 7   0.488845 NaN NaN NaN NaN
# 10  0.440583 NaN NaN NaN NaN

# %%
df.is_forecastable.unique()
# Out:
# array([ True, False])

# %%
df.market_code.unique()
# Out:
# array(['BR', 'CN', 'HK', 'IN', 'KR', 'MM', 'TH'], dtype=object)

# %%
all_files
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 all_files
#
# NameError: name 'all_files' is not defined

# %%
# UTF-8
# python 3.11.4


import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import os


path = r'/Users/i0557167/Documents/Git/Statistical-Forecasting/adjcov-dist/data/' # use your path
all_files = glob.glob(os.path.join(path, "*.csv"))

df = pd.concat((pd.read_csv(f) for f in all_files), ignore_index=True)


#df = pd.read_csv('/Users/i0557167/Documents/Git/Statistical-Forecasting/adjcov-dist/data/dataMA.csv')

sanofi_colors = ["#7A00E6","#23004C","#CA8FFF","#007FAD","#F38DE4"]
sns.set_palette(sns.color_palette(sanofi_colors))



# filter rows


df_forecastable_BR = df.loc[(df.is_forecastable == True) & (df.market_code == 'BR')] 
df_forecastable_KR = df.loc[(df.is_forecastable == True) & (df.market_code == 'KR')] 
df_forecastable_TH = df.loc[(df.is_forecastable == True) & (df.market_code == 'TH')] 
df_forecastable_HK = df.loc[(df.is_forecastable == True) & (df.market_code == 'HK')] 
df_forecastable_IN = df.loc[(df.is_forecastable == True) & (df.market_code == 'IN')] 

# selec columns
df_BR = df_forecastable_BR.loc[:,['acov']]
df_KR = df_forecastable_KR.loc[:,['acov']]
df_TH = df_forecastable_TH.loc[:,['acov']]
df_HK = df_forecastable_HK.loc[:,['acov']]
df_IN = df_forecastable_IN.loc[:,['acov']]

# bind columns into a new dataframe

combined_dfs = pd.DataFrame({'BR': df_BR['acov'],
                             'KR': df_KR['acov'],
                             'TH': df_TH['acov'],
                             'HK': df_HK['acov'],
                             'IN': df_IN['acov']})
print(combined_dfs.head())

df_BR.describe()
df_KR.describe()
df_TH.describe()
df_HK.describe()
df_IN.describe()

combined_dfs.BR.describe()

#df_forecastable_sort = df_forecastable.sort_values(by='acov')

#df_final = df_forecastable_sort.loc[:,['forecast_item','acov']]

#df_final.describe()

ax = sns.boxplot(data=combined_dfs)

#x, y = ax.lines[0].get_data()



#x = sorted(x.tolist())
#y = sorted(y.tolist())

#gmid_dict = {'DORFLEX': 619108,'NOVALGINA': 333533,'OS_CAL_D': 779523,'DERMACYD': 549502}

#df_final['forecast_item'] = df_final['forecast_item'].map(lambda x: str(x)[4:])
#df_final

#for gmid in gmid_dict.values():
    
 #   x = df_final.loc[df_final.forecast_item == str(gmid)]['acov'].values[0]
  #  ax.text(x, 1+x , list(gmid_dict.keys())[list(gmid_dict.values()).index(gmid)])
   # ax.axvline(x, ymax = 0.35, ls = '--')


#ax.axhline(0.65,ls = '--')
# Out:
#             BR  KR  TH  HK  IN
# 2625  0.512710 NaN NaN NaN NaN
# 2626  0.503969 NaN NaN NaN NaN
# 2631  0.491780 NaN NaN NaN NaN
# 2632  0.488845 NaN NaN NaN NaN
# 2635  0.440583 NaN NaN NaN NaN

# %%
df.market_code.unique()
# Out:
# array(['AR', 'CZ', 'HU', 'MD', 'PL', 'RO', 'SK', 'TN', 'DT', 'ES', 'FR',
#        'IT', 'PT', 'AE', 'AT', 'BE', 'CH', 'CY', 'DE', 'GB', 'GR', 'NL',
#        'IE', 'DZ', 'EG', 'MA', nan, 'SA', 'TR', 'ZA', 'BR', 'JP', 'US',
#        'CN', 'HK', 'IN', 'KR', 'MM', 'TH', 'CA', 'TW'], dtype=object)

# %%
df.market_code.isna().sum()
# Out:
# 52

# %%
df
# Out:
#      market_code forecast_item        date        baseline item_usage_rule  \
# 0             AR    AR: 623617  2023-10-01  2. Statistical             Use
# 1             AR    AR: 661788  2023-10-01  2. Statistical             Use
# 2             AR    AR: 698558  2023-10-01       1. Manual          Ignore
# 3             AR    AR: 715504  2023-10-01  2. Statistical             Use
# 4             AR    AR: 715568  2023-10-01       1. Manual          Ignore
# ...          ...           ...         ...             ...             ...
# 4140          CA    CA: 823208  2023-10-01       1. Manual          Ignore
# 4141          CA    CA: 827763  2023-10-01       1. Manual          Ignore
# 4142          CA    CA: 839666  2023-10-01       1. Manual          Ignore
# 4143          CA    CA: 866982  2023-10-01       1. Manual          Ignore
# 4144          TW    TW: 416606  2023-10-01       1. Manual          Ignore
#
#       buckets  intermit  adj_mean  adj_dev      acov  is_forecastable  \
# 0          81  0.083333   23518.0  11428.0  0.485926             True
# 1          75  0.000000   54301.0  15370.0  0.283052             True
# 2          64  0.500000    2207.0   2891.0  1.309923            False
# 3          75  0.166667   35086.0  14834.0  0.422790             True
# 4          38  0.333333   27146.0  48271.0  1.778199            False
# ...       ...       ...       ...      ...       ...              ...
# 4140       69       NaN     558.0   1852.0  3.318996            False
# 4141       19       NaN       0.0      0.0       NaN            False
# 4142       19       NaN       0.0      0.0       NaN            False
# 4143       25       NaN       0.0      0.0       NaN            False
# 4144       78       NaN       0.0      0.0       NaN            False
#
#       is_seasonal
# 0            True
# 1            True
# 2            True
# 3            True
# 4           False
# ...           ...
# 4140         True
# 4141        False
# 4142        False
# 4143        False
# 4144        False
#
# [4145 rows x 12 columns]

# %%
# UTF-8
# python 3.11.4


import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import os


path = r'/Users/i0557167/Documents/Git/Statistical-Forecasting/adjcov-dist/data/' # use your path
all_files = glob.glob(os.path.join(path, "*.csv"))

df = pd.concat((pd.read_csv(f) for f in all_files), ignore_index=True)
df_forecastable = df.loc[df.is_forecastable == True]

#df = pd.read_csv('/Users/i0557167/Documents/Git/Statistical-Forecasting/adjcov-dist/data/dataMA.csv')

sanofi_colors = ["#7A00E6","#23004C","#CA8FFF","#007FAD","#F38DE4"]
sns.set_palette(sns.color_palette(sanofi_colors))



# filter rows


df_forecastable_BR = df.loc[(df.is_forecastable == True) & (df.market_code == 'BR')] 
df_forecastable_KR = df.loc[(df.is_forecastable == True) & (df.market_code == 'KR')] 
df_forecastable_TH = df.loc[(df.is_forecastable == True) & (df.market_code == 'TH')] 
df_forecastable_HK = df.loc[(df.is_forecastable == True) & (df.market_code == 'HK')] 
df_forecastable_IN = df.loc[(df.is_forecastable == True) & (df.market_code == 'IN')] 

# selec columns
df_BR = df_forecastable_BR.loc[:,['acov']]
df_KR = df_forecastable_KR.loc[:,['acov']]
df_TH = df_forecastable_TH.loc[:,['acov']]
df_HK = df_forecastable_HK.loc[:,['acov']]
df_IN = df_forecastable_IN.loc[:,['acov']]

# bind columns into a new dataframe

combined_dfs = pd.DataFrame({'BR': df_BR['acov'],
                             'KR': df_KR['acov'],
                             'TH': df_TH['acov'],
                             'HK': df_HK['acov'],
                             'IN': df_IN['acov']})
print(combined_dfs.head())

df_BR.describe()
df_KR.describe()
df_TH.describe()
df_HK.describe()
df_IN.describe()

combined_dfs.BR.describe()

#df_forecastable_sort = df_forecastable.sort_values(by='acov')

#df_final = df_forecastable_sort.loc[:,['forecast_item','acov']]

#df_final.describe()

ax = sns.boxplot(data=combined_dfs)

#x, y = ax.lines[0].get_data()



#x = sorted(x.tolist())
#y = sorted(y.tolist())

#gmid_dict = {'DORFLEX': 619108,'NOVALGINA': 333533,'OS_CAL_D': 779523,'DERMACYD': 549502}

#df_final['forecast_item'] = df_final['forecast_item'].map(lambda x: str(x)[4:])
#df_final

#for gmid in gmid_dict.values():
    
 #   x = df_final.loc[df_final.forecast_item == str(gmid)]['acov'].values[0]
  #  ax.text(x, 1+x , list(gmid_dict.keys())[list(gmid_dict.values()).index(gmid)])
   # ax.axvline(x, ymax = 0.35, ls = '--')


#ax.axhline(0.65,ls = '--')
# Out:
#             BR  KR  TH  HK  IN
# 2625  0.512710 NaN NaN NaN NaN
# 2626  0.503969 NaN NaN NaN NaN
# 2631  0.491780 NaN NaN NaN NaN
# 2632  0.488845 NaN NaN NaN NaN
# 2635  0.440583 NaN NaN NaN NaN

# %%
df_forecastable.market_code.isna().sum()
# Out:
# 5
